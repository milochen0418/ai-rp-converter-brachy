# %% [markdown]
# # ONE Tandem

# %%
# oneTandem_RP.34765539.20190307.f34765539_20190307.dcm
import pydicom
import os

rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\oneTandem_RP.34765539.20190307.f34765539-20191114.dcm'
rp_fp = pydicom.read_file(rp_filepath)
rp_fp.ApplicationSetupSequence[0].ChannelSequence[0]
# Out:
# (3006, 0084) Referenced ROI Number               IS: "20"
# (300a, 0110) Number of Control Points            IS: "22"
# (300a, 0282) Channel Number                      IS: "1"
# (300a, 0284) Channel Length                      DS: "1300"
# (300a, 0286) Channel Total Time                  DS: "270.000000015845"
# (300a, 0288) Source Movement Type                CS: 'STEPWISE'
# (300a, 0290) Source Applicator Number            IS: "1"
# (300a, 0291) Source Applicator ID                SH: 'Tandem'
# (300a, 0292) Source Applicator Type              CS: 'RIGID'
# (300a, 0294) Source Applicator Name              LO: ''
# (300a, 0296) Source Applicator Length            DS: "1300"
# (300a, 02a0) Source Applicator Step Size         DS: "5"
# (300a, 02a2) Transfer Tube Number                IS: ''
# (300a, 02c8) Final Cumulative Time Weight        DS: "270.000000015845"
# (300a, 02d0)  Brachy Control Point Sequence   44 item(s) ----
# ...

# %% [markdown]
# # NEW RP

# %%
# NEW RP
import pydicom
import os

#rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\Study-LinCY-vReverse_RP_Files\RP.34765539.20190307.f34765539_20190307.dcm'
rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\new_RP.34765539.20190307.f34765539_20190307.dcm'
rp_fp = pydicom.read_file(rp_filepath)
rp_fp.ApplicationSetupSequence[0].ChannelSequence[4]
# Out:
# (3006, 0084) Referenced ROI Number               IS: "16"
# (300a, 0110) Number of Control Points            IS: "13"
# (300a, 0282) Channel Number                      IS: "5"
# (300a, 0284) Channel Length                      DS: "1300"
# (300a, 0286) Channel Total Time                  DS: "40.0000000091595"
# (300a, 0288) Source Movement Type                CS: 'STEPWISE'
# (300a, 0290) Source Applicator Number            IS: "1"
# (300a, 0291) Source Applicator ID                SH: 'Lt implant'
# (300a, 0292) Source Applicator Type              CS: 'RIGID'
# (300a, 0294) Source Applicator Name              LO: ''
# (300a, 0296) Source Applicator Length            DS: "1300"
# (300a, 02a0) Source Applicator Step Size         DS: "5"
# (300a, 02a2) Transfer Tube Number                IS: ''
# (300a, 02c8) Final Cumulative Time Weight        DS: "40.0000000091595"
# (300a, 02d0)  Brachy Control Point Sequence   26 item(s) ----
# ...

# %% [markdown]
# ### OLD RP

# %%
# OLD RP
import pydicom
import os

#rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\Study-LinCY-vReverse_RP_Files\RP.34765539.20190307.f34765539_20190307.dcm'
rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\old_RP.34765539.20190307.f34765539_20190307.dcm'
rp_fp = pydicom.read_file(rp_filepath)
rp_fp
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0012) Instance Creation Date              DA: '20190307'
# (0008, 0013) Instance Creation Time              TM: '144307.15399999998'
# (0008, 0016) SOP Class UID                       UI: RT Plan Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.246.352.71.5.417454940236.2060926.20190307884072
# (0008, 0020) Study Date                          DA: '20190307'
# (0008, 0030) Study Time                          TM: '103646.613000'
# (0008, 0050) Accession Number                    SH: '2019-10-08-09:42'
# (0008, 0060) Modality                            CS: 'RTPLAN'
# (0008, 0070) Manufacturer                        LO: 'Varian Medical Systems'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'ARIA136SQL'
# (0008, 1030) Study Description                   LO: 'Pelvis^3_IC (Adult)'
# ...

# %% [markdown]
# # Current RP Template

# %%
# RP Template
import pydicom
import os

rp_filepath = r'RP_Template_Brachy_24460566_implant-5_20191113/RP.1.2.246.352.71.5.417454940236.2060926.20191008103753.dcm'
rp_fp = pydicom.read_file(rp_filepath)
rp_fp
#rp_fp.ApplicationSetupSequence[0].ChannelSequence[0]
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0012) Instance Creation Date              DA: '20191113'
# (0008, 0013) Instance Creation Time              TM: '114356.404000'
# (0008, 0016) SOP Class UID                       UI: RT Plan Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.246.352.71.5.417454940236.2060926.20191008103753
# (0008, 0020) Study Date                          DA: '20191008'
# (0008, 0030) Study Time                          TM: '092849.803000'
# (0008, 0050) Accession Number                    SH: '2019-10-08-09:42'
# (0008, 0060) Modality                            CS: 'RTPLAN'
# (0008, 0070) Manufacturer                        LO: 'Varian Medical Systems'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'ARIA136SQL'
# (0008, 1030) Study Description                   LO: 'Pelvis^3_IC (Adult)'
# ...

# %% [markdown]
# # OLD RP Template

# %%
# OLD RP Template
import pydicom
import os

rp_filepath = r'RP_Template/Brachy_RP.1.2.246.352.71.5.417454940236.2063186.20191015164204.dcm'
rp_fp = pydicom.read_file(rp_filepath)
rp_fp
#rp_fp.ApplicationSetupSequence[0].ChannelSequence[0]
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0012) Instance Creation Date              DA: '20191015'
# (0008, 0013) Instance Creation Time              TM: '164400.648000'
# (0008, 0016) SOP Class UID                       UI: RT Plan Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.246.352.71.5.417454940236.2063186.20191015164204
# (0008, 0020) Study Date                          DA: '20191015'
# (0008, 0030) Study Time                          TM: '103307.760000'
# (0008, 0050) Accession Number                    SH: '2019-10-15-10:36'
# (0008, 0060) Modality                            CS: 'RTPLAN'
# (0008, 0070) Manufacturer                        LO: 'Varian Medical Systems'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'ARIA136SQL'
# (0008, 1030) Study Description                   LO: 'Pelvis^3_IC (Adult)'
# ...

# %%
import pydicom
import os

rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\ThreeLines_RP.34765539.20190307.f34765539-20191114.dcm'
rp_fp = pydicom.read_file(rp_filepath)
rp_fp.ApplicationSetupSequence[0].ChannelSequence[3]
#ThreeLines_RP.34765539.20190307.f34765539-20191114.dcm
# Out:
# (3006, 0084) Referenced ROI Number               IS: "18"
# (300a, 0110) Number of Control Points            IS: "22"
# (300a, 0282) Channel Number                      IS: "4"
# (300a, 0284) Channel Length                      DS: "1300"
# (300a, 0286) Channel Total Time                  DS: "10.0000000013438"
# (300a, 0288) Source Movement Type                CS: 'STEPWISE'
# (300a, 0290) Source Applicator Number            IS: "1"
# (300a, 0291) Source Applicator ID                SH: 'Rt implant'
# (300a, 0292) Source Applicator Type              CS: 'RIGID'
# (300a, 0294) Source Applicator Name              LO: ''
# (300a, 0296) Source Applicator Length            DS: "1300"
# (300a, 02a0) Source Applicator Step Size         DS: "5"
# (300a, 02a2) Transfer Tube Number                IS: ''
# (300a, 02c8) Final Cumulative Time Weight        DS: "10.0000000013438"
# (300a, 02d0)  Brachy Control Point Sequence   22 item(s) ----
# ...

# %%
import pydicom
import os
rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\oneTandem_RP.34765539.20190307.f34765539-20191114.dcm'
rp_fp = pydicom.read_file(rp_filepath)
bcpSeq = rp_fp.ApplicationSetupSequence[0].ChannelSequence[0].BrachyControlPointSequence
rp_line = []
for idx, item in enumerate(bcpSeq):
    if idx % 2 != 1:
        continue
    pt = [ float(v) for v in item.ControlPoint3DPosition]
    rp_line.append(pt)

print('rp_line = {}'.format(rp_line))
# Out:
# rp_line = [[1.7578125, -153.2990817077104, 3.112824585869329], [2.5052824935845694, -151.3591525192463, -1.3270463671529955], [1.8230818008579892, -149.56477389828402, -5.834178820392904], [2.3337019547051505, -147.7622835905897, -10.44855400809037], [2.8601411506082743, -146.24923384939171, -15.143922691114366], [2.9929896008738566, -144.55388539912613, -19.824106756474148], [3.550663657290856, -143.60558634270913, -24.679397925329184], [3.724019664797692, -142.6378981704046, -29.566980683764182], [4.1015625, -141.71207876574687, -34.374156719376025], [4.4921875, -140.76073826703873, -39.245020072761754], [4.624425626094952, -140.18807437390504, -44.177059205606156], [4.8828125, -139.9296875, -49.127520528866], [5.2734375, -139.1484375, -54.01483882464324], [5.2734375, -138.8580572696224, -58.98674677953321], [5.6640625, -138.3671875, -63.90146896705856], [6.0546875, -137.9765625, -68.82657721536403], [6.0546875, -137.5305797216356, -73.78343182522566], [6.4453125, -137.1953125, -78
# ...

# %%
#plot_rp_file_tandem()
#def plot_rp_file_tandem(dicom_dict, rp_filepath):

# %% [markdown]
# # Process RP file by hand

# %%
import pydicom
import os

#rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\RP.34765539.20190307.f34765539_20191115.dcm'
rp_filepath = r'LinCY-RP-Compare\RP.34135696.20190618.f34135696_20191115.dcm'
rp_fp = pydicom.read_file(rp_filepath)
print('len of ChnanelSequence = {}'.format(len(rp_fp.ApplicationSetupSequence[0].ChannelSequence)))
for channel_idx, channelSeq in enumerate(rp_fp.ApplicationSetupSequence[0].ChannelSequence):
    print('\n\n\n[  channel_dx = {}   ]'.format(channel_idx))
    print(channelSeq)
# Out:
# len of ChnanelSequence = 5
#
#
#
# [  channel_dx = 0   ]
# (3006, 0084) Referenced ROI Number               IS: "25"
# (300a, 0110) Number of Control Points            IS: "24"
# (300a, 0282) Channel Number                      IS: "1"
# (300a, 0284) Channel Length                      DS: "1300"
# (300a, 0286) Channel Total Time                  DS: "0"
# (300a, 0288) Source Movement Type                CS: 'STEPWISE'
# (300a, 0290) Source Applicator Number            IS: "1"
# (300a, 0291) Source Applicator ID                SH: 'Tandem'
# (300a, 0292) Source Applicator Type              CS: 'RIGID'
# (300a, 0294) Source Applicator Name              LO: ''
# (300a, 0296) Source Applicator Length            DS: "1300"
# (300a, 02a0) Source Applicator Step Size         DS: "5"
# (300a, 02a2) Transfer Tube Number                IS: ''
# (300a, 02c8) Final Cumulative Time Weight        DS: "0"
# (300a, 02d0)  Brachy Control Point Sequence   48 item(s) ----
# ...

# %%
# Process to keep Three Lines
import pydicom
import os
import copy

#rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\RP.34765539.20190307.f34765539_20191115.dcm'
#rp_filepath = r'LinCY-RP-Compare\RP.34135696.20190618.f34135696_20191115.dcm'
rp_filepath = r'LinCY-RP-Compare\RP.34135696.20190618.f34135696-3.dcm'
#rp_out_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\ThreeLines_RP.34765539.20190307.f34765539_20191115.dcm'
#rp_out_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\ThreeLines_RP.34135696.20190618.f34135696_20191115.dcm'
rp_out_filepath = r'LinCY-RP-Compare\ThreeLines_RP.34135696.20190618.f34135696-3.dcm'
rp_fp = pydicom.read_file(rp_filepath)
rp_fp.ApplicationSetupSequence[0].ChannelSequence = copy.deepcopy(rp_fp.ApplicationSetupSequence[0].ChannelSequence[0:3])
pydicom.write_file(rp_out_filepath, rp_fp)

# %%
# Show ThreeLines RP 
import pydicom
import os 
#rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\ThreeLines_RP.34765539.20190307.f34765539_20191115.dcm'
#rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\ThreeLines_RP.34135696.20190618.f34135696_20191115.dcm'
rp_filepath = r'LinCY-RP-Compare\ThreeLines_RP.34135696.20190618.f34135696-3.dcm'
rp_fp = pydicom.read_file(rp_filepath)
for idx, seq in enumerate(rp_fp.ApplicationSetupSequence[0].ChannelSequence):
    print(seq.SourceApplicatorID)
# Out:
# Tandem
# Rt_Ovoid
# Lt_Ovoid

# %%
# Process to keep Last needle
import pydicom
import os
import copy

rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\RP.34765539.20190307.f34765539_20191115.dcm'
rp_out_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\LastLine_RP.34765539.20190307.f34765539_20191115.dcm'
rp_fp = pydicom.read_file(rp_filepath)
channels_length = len(rp_fp.ApplicationSetupSequence[0].ChannelSequence)
rp_fp.ApplicationSetupSequence[0].ChannelSequence = copy.deepcopy(rp_fp.ApplicationSetupSequence[0].ChannelSequence[-1: channels_length])
pydicom.write_file(rp_out_filepath, rp_fp)

# %%
# kill 25
import pydicom
import os 
import copy
#rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\LastLine_RP.34765539.20190307.f34765539_20191115.dcm'
#rp_filepath = r'Study-LinCY-vReverse_RP_Files\RP.34135696.20190618.f34135696-4.dcm'
#rp_filepath = r'Study-LinCY-vReverse_RP_Files\RP.34135696.20190618.f34135696-4.dcm'
#rp_filepath = r'Study-LinCY-vReverse_RP_Files\RP.34135696.20190618.fTBOX232-34135696-20190618.dcm'
#rp_out_filepath = r'Study-LinCY-vReverse_RP_Files\RP.34135696.20190618.fTBOX232-34135696-20190618-new.dcm'

rp_filepath = r'Study-LinCY-vReverse_RP_Files\RP.24460566.20191008.f24460566-2.dcm'
rp_out_filepath = r'Study-LinCY-vReverse_RP_Files\RP.24460566.20191008.f24460566-2-new.dcm'
rp_fp = pydicom.read_file(rp_filepath)
#print(len(rp_fp.ApplicationSetupSequence[0].ChannelSequence))
rp_fp.ApplicationSetupSequence[0].ChannelSequence = copy.deepcopy(rp_fp.ApplicationSetupSequence[0].ChannelSequence[0:4])
pydicom.write_file(rp_out_filepath, rp_fp)

# %%
# Show LastLine RP
import pydicom
import os 
#rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\LastLine_RP.34765539.20190307.f34765539_20191115.dcm'
#rp_filepath = r'Study-LinCY-vReverse_RP_Files\RP.34135696.20190618.f34135696-4.dcm'
#rp_filepath = r'Study-LinCY-vReverse_RP_Files\RP.34135696.20190618.f34135696-4.dcm'
rp_filepath = r'Study-LinCY-vReverse_RP_Files\RP.24460566.20191008.f24460566-2-new.dcm'
rp_fp = pydicom.read_file(rp_filepath)
print(len(rp_fp.ApplicationSetupSequence[0].ChannelSequence))
for idx, seq in enumerate(rp_fp.ApplicationSetupSequence[0].ChannelSequence):
    print(seq)
    
    

#rp_fp
# Out:
# 4
# (3006, 0084) Referenced ROI Number               IS: "19"
# (300a, 0110) Number of Control Points            IS: "25"
# (300a, 0282) Channel Number                      IS: "1"
# (300a, 0284) Channel Length                      DS: "1300"
# (300a, 0286) Channel Total Time                  DS: "0"
# (300a, 0288) Source Movement Type                CS: 'STEPWISE'
# (300a, 0290) Source Applicator Number            IS: "1"
# (300a, 0291) Source Applicator ID                SH: 'Tandem'
# (300a, 0292) Source Applicator Type              CS: 'RIGID'
# (300a, 0294) Source Applicator Name              LO: ''
# (300a, 0296) Source Applicator Length            DS: "1300"
# (300a, 02a0) Source Applicator Step Size         DS: "5"
# (300a, 02a2) Transfer Tube Number                IS: ''
# (300a, 02c8) Final Cumulative Time Weight        DS: "0"
# (300a, 02d0)  Brachy Control Point Sequence   50 item(s) ----
#    (300a, 0112) Control Point Index                 IS: "0"
# ...

# %%
import pydicom
import os 
#rs_filepath = r'Study-LinCY-vReverse\34765539_20191115\RS.1.2.246.352.71.4.417454940236.290962.20191115090506.dcm'
#rs_filepath = r'Study-LinCY-vReverse\34765539_20191115\RS.1.2.246.352.71.4.417454940236.290962.20191115090506.dcm'
#rs_filepath = r'Study-LinCY-vReverse\34135696-3\RS.1.2.246.352.71.4.417454940236.291098.20191115163849.dcm'
#rs_filepath = r'Study-LinCY-vReverse\34135696_20191115\RS.1.2.246.352.71.4.417454940236.291097.20191115161148.dcm'
#rs_filepath = r'Study-LinCY-vReverse\34765539_20190307\RS.1.2.246.352.71.4.417454940236.290875.20191114145400.dcm'
#rs_filepath = r'Study-LinCY-vReverse\34135696-4\RS.1.2.246.352.71.4.417454940236.291099.20191115165220.dcm'
#rs_filepath = r'Study-LinCY-vReverse\24460566-2\RS.1.2.246.352.71.4.417454940236.291100.20191115180615.dcm'
rs_filepath = r'Study-LinCY-vReverse\TBOX232-34135696-20190618\RS.1.2.246.352.71.4.417454940236.273898.20190618100037.dcm'
rs_fp = pydicom.read_file(rs_filepath)
for item in rs_fp.StructureSetROISequence:
    print(item)
# Out:
# (3006, 0022) ROI Number                          IS: "1"
# (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.95999.30000019061800061946900000010
# (3006, 0026) ROI Name                            LO: 'BODY'
# (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
# (3006, 0022) ROI Number                          IS: "2"
# (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.95999.30000019061800061946900000010
# (3006, 0026) ROI Name                            LO: 'Gause'
# (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
# (3006, 0022) ROI Number                          IS: "3"
# (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.95999.30000019061800061946900000010
# (3006, 0026) ROI Name                            LO: 'Bladder'
# (3006, 0036) ROI Generation Algorithm            CS: 'MANUAL'
# (3006, 0022) ROI Number                          IS: "4"
# ...

# %%
rp_filepath = r'C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\LastLine_RP.34765539.20190307.f34765539_20191115.dcm'
print('plot_rp_file(dicom_dict, rp_filepath={})'.format(rp_filepath))
rp_fp = pydicom.read_file(rp_filepath)
bcpSeq = rp_fp.ApplicationSetupSequence[0].ChannelSequence[0].BrachyControlPointSequence
rp_line = []
for idx, item in enumerate(bcpSeq):
    if idx % 2 != 1:
        continue
    pt = [float(v) for v in item.ControlPoint3DPosition]
    rp_line.append(pt)
    print('tandem rp_line = {}'.format(rp_line))
pass
# Out:
# plot_rp_file(dicom_dict, rp_filepath=C:\Users\Milo\Desktop\git\ai-rp-converter-brachy\LinCY-RP-Compare\LastLine_RP.34765539.20190307.f34765539_20191115.dcm)
# tandem rp_line = [[8.959750200753666, -149.56586304285503, -37.529361798752845]]
# tandem rp_line = [[8.959750200753666, -149.56586304285503, -37.529361798752845], [9.5703125, -148.9140625, -42.42510824830546]]
# tandem rp_line = [[8.959750200753666, -149.56586304285503, -37.529361798752845], [9.5703125, -148.9140625, -42.42510824830546], [9.925624389733956, -148.16812561026603, -47.319196875437854]]
# tandem rp_line = [[8.959750200753666, -149.56586304285503, -37.529361798752845], [9.5703125, -148.9140625, -42.42510824830546], [9.925624389733956, -148.16812561026603, -47.319196875437854], [10.490412889684832, -147.60333711031518, -52.210913995186345]]
# ...

# %%
# Read RP
import pydicom
import os
rp_filepath =r'Study-LinCY-vReverse_RP_Files\RP.34135696.20190618.fTBOX232-34135696-20190618-new.dcm'
pydicom.read_file(rp_filepath)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0012) Instance Creation Date              DA: '20190618'
# (0008, 0013) Instance Creation Time              TM: '171904.756'
# (0008, 0016) SOP Class UID                       UI: RT Plan Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.246.352.71.5.417454940236.2077416.20190618669570
# (0008, 0020) Study Date                          DA: '20190618'
# (0008, 0030) Study Time                          TM: '091126.987000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RTPLAN'
# (0008, 0070) Manufacturer                        LO: 'Varian Medical Systems'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'ARIA136SQL'
# (0008, 1030) Study Description                   LO: 'Pelvis^3_IC (Adult)'
# (0008, 103e) Series Description                  LO: 'ARIA RadOnc Plans'
# ...

# %%
rs_filepath = r'Study-LinCY-vReverse\TBOX232-34135696-20190618\RS.1.2.246.352.71.4.417454940236.273898.20190618100037.dcm' 
rs_fp = pydicom.read_file(rs_filepath)
print(rs_fp)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0012) Instance Creation Date              DA: '20191115'
# (0008, 0013) Instance Creation Time              TM: '171904.755000'
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.246.352.71.4.417454940236.273898.20190618100037
# (0008, 0020) Study Date                          DA: '20190618'
# (0008, 0030) Study Time                          TM: '091126.987000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RTSTRUCT'
# (0008, 0070) Manufacturer                        LO: 'Varian Medical Systems'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'ARIA136SQL'
# (0008, 1030) Study Description                   LO: 'Pelvis^3_IC (Adult)'
# ...

# %% [markdown]
# # The code to checking rp_line length limit setting

# %%
# Process case of 804045
# Description from Dr. Wang:
# there is only needle and the number of light points is too short on the needle

# %%
import pydicom
import os
output_root_folder = r'import_output'
output_folder = r'804045.20190326.f804045'
#output_folder = r'35413048.20190905.f35413048-1'
output_folder_filepath = os.path.join(output_root_folder, output_folder)
rp_filepath = ''
rs_filepath = ''
for file in os.listdir(output_folder_filepath):
    filepath = os.path.join(output_folder_filepath, file)
    fp = pydicom.read_file(filepath)
    if fp.Modality == 'RTPLAN':
        rp_filepath = filepath
    elif fp.Modality == 'RTSTRUCT':
        rs_filepath = filepath
        
def get_HR_CTV_min_z(rs_filepath):
    HR_CT_ROINumber = -1
    rs_fp = pydicom.read_file(rs_filepath)
    for roiSeq in rs_fp.StructureSetROISequence:
        if roiSeq.ROIName == 'HR-CTV':
            #print('ROI_Number = {}'.format(roiSeq.ROINumber))
            HR_CT_ROINumber = roiSeq.ROINumber
            break
    hrctv_roicseq_idx = -1        
    for c_idx, roiCSeq in enumerate(rs_fp.ROIContourSequence):
        if roiCSeq.ReferencedROINumber == HR_CT_ROINumber:
            hrctv_roicseq_idx = c_idx
            break
        
    min_z = rs_fp.ROIContourSequence[hrctv_roicseq_idx].ContourSequence[0].ContourData[2]
    return min_z
        
print('rs_filepath = {}'.format(rs_filepath))
print('rp_filepath = {}'.format(rp_filepath))
rp_fp = pydicom.read_file(rp_filepath)
rs_fp = pydicom.read_file(rs_filepath)
print('HR_CTV min z = {} mm'.format(format(get_HR_CTV_min_z(rs_filepath))))
print('z_target = {} mm'.format(get_HR_CTV_min_z(rs_filepath) - 20) )
for idx, item in enumerate(rp_fp.ApplicationSetupSequence[0].ChannelSequence):
    print('\nSourceApplicatorID = {} , ChannelSequence idx {}'.format(item.SourceApplicatorID, idx))
    print(rp_fp.ApplicationSetupSequence[0].ChannelSequence[idx].BrachyControlPointSequence[-1])
# Out:
# rs_filepath = import_output\804045.20190326.f804045\RS.1.2.246.352.71.4.417454940236.290563.20191112085750.dcm
# rp_filepath = import_output\804045.20190326.f804045\RP.804045.20190326.f804045.dcm
# HR_CTV min z = -58 mm
# z_target = -78.0 mm
#
# SourceApplicatorID = Tandem , ChannelSequence idx 0
# (300a, 0112) Control Point Index                 IS: "33"
# (300a, 02d2) Control Point Relative Position     DS: "83.5"
# (300a, 02d4) Control Point 3D Position           DS: ['14.030274742500012', '-165.45681839773175', '-77.63606774885912']
# (300a, 02d6) Cumulative Time Weight              DS: "0"
#
# SourceApplicatorID = Rt_Ovoid , ChannelSequence idx 1
# (300a, 0112) Control Point Index                 IS: "13"
# (300a, 02d2) Control Point Relative Position     DS: "33.5"
# (300a, 02d4) Control Point 3D Position           DS: ['26.290566563007594', '-165.0991577080076', '-74.78693477738393']
# (300a, 02d6) Cumulative Time Weight              DS: "0"
#
# ...

# %% [markdown]
# # Find why what rp show is not in our expect

# %%
rp_fp = pydicom.read_file(rp_filepath)
rp_fp
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0012) Instance Creation Date              DA: '20190326'
# (0008, 0013) Instance Creation Time              TM: '85817.501'
# (0008, 0016) SOP Class UID                       UI: RT Plan Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.246.352.71.5.417454940236.2077416.20190326688831
# (0008, 0020) Study Date                          DA: '20190326'
# (0008, 0030) Study Time                          TM: '085927.643000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RTPLAN'
# (0008, 0070) Manufacturer                        LO: 'Varian Medical Systems'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'ARIA136SQL'
# (0008, 1030) Study Description                   LO: 'Pelvis^3_IC (Adult)'
# (0008, 103e) Series Description                  LO: 'ARIA RadOnc Plans'
# ...

# %%
from IPython.core.display import display, HTML

rp_fp = pydicom.read_file(rp_filepath)
rs_fp = pydicom.read_file(rs_filepath)
k = rp_fp.FractionGroupSequence[0]
kk = rp_fp.FractionGroupSequence[0].ReferencedBrachyApplicationSetupSequence[0]
display(kk)
print('XXXXXXXX')
display(kk[0x32491010].value)
print('XXXXX RP DATA XXXX')
display(rp_fp)
print('XXXXX RS DATA XXXX')
display(rs_fp)
# Out:
# (300c, 000c) Referenced Brachy Application Setup IS: "1"
# (3249, 0010) Private Creator                     LO: 'Varian Medical Systems VISION 3249'
# (3249, 1010) Private tag data                    UN: Array of 52 elements
# XXXXXXXX
# b'1.2.246.352.71.10.417454940236.341895.20190528100832'
# XXXXX RP DATA XXXX
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0012) Instance Creation Date              DA: '20190326'
# (0008, 0013) Instance Creation Time              TM: '85817.501'
# (0008, 0016) SOP Class UID                       UI: RT Plan Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.246.352.71.5.417454940236.2077416.20190326688831
# (0008, 0020) Study Date                          DA: '20190326'
# (0008, 0030) Study Time                          TM: '085927.643000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RTPLAN'
# ...

# %%
#rp_template_filepath = r'RP_Template_34135696_20191115/RP.1.2.246.352.71.5.417454940236.2077416.20191115161213.dcm'
rp_template_filepath = r'RP_Template/Brachy_RP.1.2.246.352.71.5.417454940236.2063186.20191015164204.dcm'
rp_template_fp = pydicom.read_file(rp_template_filepath)
rp_template_fp

k = rp_template_fp.FractionGroupSequence[0]
kk = rp_template_fp.FractionGroupSequence[0].ReferencedBrachyApplicationSetupSequence[0]
display(kk)
print('XXXXXXXX')
display(kk[0x32491010].value)

print('XXXXXXXX')
#display(rp_template_fp)
# Out:
# (300c, 000c) Referenced Brachy Application Setup IS: "1"
# (3249, 0010) Private Creator                     LO: 'Varian Medical Systems VISION 3249'
# (3249, 1010) Private tag data                    UN: Array of 52 elements
# XXXXXXXX
# b'1.2.246.352.71.10.417454940236.354700.20191008143159'
# XXXXXXXX

# %%
k = rp_template_fp.FractionGroupSequence[0].ReferencedBrachyApplicationSetupSequence[0]

# %%
k[3249,1010]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-3d0d1d661541> in <module>()
# ----> 1 k[3249,1010]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pydicom-1.3.0-py3.6.egg\pydicom\dataset.py in __getitem__(self, key)
#     814         else:
#     815             tag = Tag(key)
# --> 816         data_elem = self._dict[tag]
#     817
#     818         if isinstance(data_elem, DataElement):
#
# KeyError: (0cb1, 03f2)

# %%
# Process data

# %%
import pydicom
import os
folder = r'C:\Users\Milo\Desktop\35025594\MR +C'
file = r'MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.558.dcm'
filepath = os.path.join(folder, file)
print(filepath)
fp = pydicom.read_file(filepath)
# Out:
# C:\Users\Milo\Desktop\35025594\MR +C\MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.558.dcm

# %%
display(fp)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OTHER']
# (0008, 0012) Instance Creation Date              DA: '20191120'
# (0008, 0013) Instance Creation Time              TM: '104450.457000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.840.113619.2.259.5399.8108306.20763.1571012701.558
# (0008, 0020) Study Date                          DA: '20191022'
# (0008, 0021) Series Date                         DA: '20191022'
# (0008, 0023) Content Date                        DA: '20191022'
# (0008, 0030) Study Time                          TM: '101833'
# (0008, 0031) Series Time                         TM: '103635'
# (0008, 0033) Content Time                        TM: '103635'
# (0008, 0050) Accession Number                    SH: 'R335883'
# (0008, 0060) Modality                            CS: 'MR'
# ...

# %% [markdown]
# # Dr. Wang say compare these file (Idea from Dr. Wang)
#
#
#
# # The same for every file
# ## Study Instance UID
# All this uid in different file and different folder are the same
#
# ## Series Instance UID
# If the file in the same folder, this uid should be the same
# If the file is in the different folder, this uid should be different
#
# ## Frame of Reference UID
# All are the same
#
# # Different for each file
# ## SOP Instance UID
# It will different for each file

# %%
import pydicom
import os
filelist_dict = {}
functional_dict = {} 
patient_folder = r"C:/Users/Milo/Desktop/35025594/"
for folder_name in os.listdir(patient_folder):
    #print(folder_name)
    functional_folder_filepath = os.path.join(patient_folder, folder_name)
    #print(functional_folder_filepath)
    functional_dict[folder_name] = functional_folder_filepath
#print(functional_dict)

for idx, functional_key in enumerate(sorted(functional_dict.keys())):
    #print('idx={}, key={} -> folder = filepath = {}'.format(idx, functional_key, functional_dict[functional_key]))
    continue

for idx, functional_key in enumerate(sorted(functional_dict.keys())):
    folder_filepath = functional_dict[functional_key]
    filelist = []
    for file in os.listdir(folder_filepath):
        filepath = os.path.join(folder_filepath, file)
        filelist.append(filepath)
    filelist_dict[functional_key] = filelist


for key in filelist_dict:
    print('\n key = {}\n'.format(key))
    for filepath in filelist_dict[key]:
        print(filepath)

    
#file = r'MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.558.dcm'
#filepath = os.path.join(folder, file)
#print(filepath)
#fp = pydicom.read_file(filepath)
# Out:
#  key = MR +C
#
# C:/Users/Milo/Desktop/35025594/MR +C\MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.558.dcm
# C:/Users/Milo/Desktop/35025594/MR +C\MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.559.dcm
# C:/Users/Milo/Desktop/35025594/MR +C\MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.560.dcm
# C:/Users/Milo/Desktop/35025594/MR +C\MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.561.dcm
# C:/Users/Milo/Desktop/35025594/MR +C\MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.562.dcm
# C:/Users/Milo/Desktop/35025594/MR +C\MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.563.dcm
# C:/Users/Milo/Desktop/35025594/MR +C\MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.564.dcm
# C:/Users/Milo/Desktop/35025594/MR +C\MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.565.dcm
# C:/Users/Milo/Desktop/35025594/MR +C\MR.1.2.840.113619.2.259.5399.8108306.20763.1571012701.566.dcm
# ...

# %%
# Observe

# %%
#attributes = ['StudyInstanceUID', 'SeriesInstanceUID', 'FrameOfReferenceUID', 'SOPInstanceUID']
#attributes = ['FrameOfReferenceUID']
#attributes = ['StudyInstanceUID']
#attributes = ['SeriesInstanceUID']
#attributes = ['FrameOfReferenceUID']
attributes = ['SOPInstanceUID']


for key in filelist_dict:
    if 'MR' in key:
        continue    
    print('\n key = {}\n'.format(key))
    for filepath in filelist_dict[key]:
        print('')
        print(os.path.basename(filepath))
        fp = pydicom.read_file(filepath)
        
        for attr in attributes:
            try:
                val = getattr(fp, attr)
                print('{} -> {}'.format(attr, val))
            except Exception as ex:
                print('Error is happend in for attr in directAttrSet. Sometimes RS file is out of control')
                print(ex)
                pass
# Out:
#  key = PETCT_20191023
#
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.1.dcm
# SOPInstanceUID -> 1.2.840.113619.2.290.3.2198477267.613.1571121477.489.11
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.10.dcm
# SOPInstanceUID -> 1.2.840.113619.2.290.3.2198477267.613.1571121477.489.101
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.100.dcm
# SOPInstanceUID -> 1.2.840.113619.2.290.3.2198477267.613.1571121477.489.1001
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.101.dcm
# SOPInstanceUID -> 1.2.840.113619.2.290.3.2198477267.613.1571121477.489.1011
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.102.dcm
# SOPInstanceUID -> 1.2.840.113619.2.290.3.2198477267.613.1571121477.489.1021
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.103.dcm
# SOPInstanceUID -> 1.2.840.113619.2.290.3.2198477267.613.1571121477.489.1031
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.104.dcm
# ...

# %%
attributes = ['StudyInstanceUID', 'SeriesInstanceUID', 'FrameOfReferenceUID', 'SOPInstanceUID']
for key in filelist_dict:
    if 'MR' in key:
        continue    
    print('\n key = {}\n'.format(key))
    for filepath in filelist_dict[key]:
        print('')
        print(os.path.basename(filepath))
        fp = pydicom.read_file(filepath)        
        for attr in attributes:
            try:
                val = getattr(fp, attr)
                val = val + '1'
                setattr(fp, attr, val)
            except Exception as ex:
                print('Error is happend in for attr in directAttrSet. Sometimes RS file is out of control')
                print(ex)
                pass
        pydicom.write_file(filepath,fp )
# Out:
#  key = PETCT_20191023
#
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.1.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.10.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.100.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.101.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.102.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.103.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.104.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.105.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.106.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.107.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.108.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.109.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.11.dcm
#
# CT.1.2.840.113619.2.290.3.2198477267.613.1571121477.489.110.dcm
#
# ...
